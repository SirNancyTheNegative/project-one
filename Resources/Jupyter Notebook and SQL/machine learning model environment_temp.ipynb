# %%
import pandas as pd

# %%
file_path = "Environment_Temperature_change_E_All_Data_NOFLAG.csv"
temp_df = pd.read_csv(file_path)
temp_df.head()
# Out:
#    Area Code         Area  Months Code    Months  Element Code  \
# 0          2  Afghanistan         7001   January          7271
# 1          2  Afghanistan         7001   January          6078
# 2          2  Afghanistan         7002  February          7271
# 3          2  Afghanistan         7002  February          6078
# 4          2  Afghanistan         7003     March          7271
#
#               Element Unit  Y1961  Y1962  Y1963  ...  Y2010  Y2011  Y2012  \
# 0  Temperature change   �C  0.777  0.062  2.744  ...  3.601  1.179 -0.583
# 1  Standard Deviation   �C  1.950  1.950  1.950  ...  1.950  1.950  1.950
# 2  Temperature change   �C -1.743  2.465  3.919  ...  1.212  0.321 -3.201
# 3  Standard Deviation   �C  2.597  2.597  2.597  ...  2.597  2.597  2.597
# 4  Temperature change   �C  0.516  1.336  0.403  ...  3.390  0.748 -0.527
#
#    Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  Y2019
# 0  1.233  1.755  1.943  3.416  1.201  1.996  2.951
# ...

# %%
temp_df.dtypes
# Out:
# Area Code         int64
# Area             object
# Months Code       int64
# Months           object
# Element Code      int64
#                  ...
# Y2015           float64
# Y2016           float64
# Y2017           float64
# Y2018           float64
# Y2019           float64
# Length: 66, dtype: object

# %%
for column in temp_df.columns:
    print(f"Column {column} has {temp_df[column].isnull().sum()}null values")
# Out:
# Column Area Code has 0null values
# Column Area has 0null values
# Column Months Code has 0null values
# Column Months has 0null values
# Column Element Code has 0null values
# Column Element has 0null values
# Column Unit has 0null values
# Column Y1961 has 1369null values
# Column Y1962 has 1334null values
# Column Y1963 has 1362null values
# Column Y1964 has 1404null values
# Column Y1965 has 1375null values
# Column Y1966 has 1292null values
# Column Y1967 has 1309null values
# Column Y1968 has 1311null values
# Column Y1969 has 1330null values
# Column Y1970 has 1348null values
# Column Y1971 has 1353null values
# Column Y1972 has 1333null values
# Column Y1973 has 1262null values
# Column Y1974 has 1282null values
# Column Y1975 has 1376null values
# Column Y1976 has 1447null values
# Column Y1977 has 1399null values
# Column Y1978 has 1329null values
# Column Y1979 has 1366null values
# Column Y1980 has 1373null values
# Column Y1981 has 1380null values
# ...

# %%
etemp_df = temp_df.dropna()

# %%
etemp_df.head()
# Out:
#    Area Code         Area  Months Code    Months  Element Code  \
# 0          2  Afghanistan         7001   January          7271
# 1          2  Afghanistan         7001   January          6078
# 2          2  Afghanistan         7002  February          7271
# 3          2  Afghanistan         7002  February          6078
# 4          2  Afghanistan         7003     March          7271
#
#               Element Unit  Y1961  Y1962  Y1963  ...  Y2010  Y2011  Y2012  \
# 0  Temperature change   �C  0.777  0.062  2.744  ...  3.601  1.179 -0.583
# 1  Standard Deviation   �C  1.950  1.950  1.950  ...  1.950  1.950  1.950
# 2  Temperature change   �C -1.743  2.465  3.919  ...  1.212  0.321 -3.201
# 3  Standard Deviation   �C  2.597  2.597  2.597  ...  2.597  2.597  2.597
# 4  Temperature change   �C  0.516  1.336  0.403  ...  3.390  0.748 -0.527
#
#    Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  Y2019
# 0  1.233  1.755  1.943  3.416  1.201  1.996  2.951
# ...

# %%
print(f"duplicate entries: {etemp_df.duplicated().sum()}")
# Out:
# duplicate entries: 0

# %%
file_path = "environment_temperature_change_cleaned.csv"
etemp_df.to_csv(file_path, index=False)

# %%
file_path = "environment_temperature_change_cleaned.csv"
etemp_df = pd.read_csv(file_path)
etemp_df.head()
# Out:
#    Area Code         Area  Months Code    Months  Element Code  \
# 0          2  Afghanistan         7001   January          7271
# 1          2  Afghanistan         7001   January          6078
# 2          2  Afghanistan         7002  February          7271
# 3          2  Afghanistan         7002  February          6078
# 4          2  Afghanistan         7003     March          7271
#
#               Element Unit  Y1961  Y1962  Y1963  ...  Y2010  Y2011  Y2012  \
# 0  Temperature change   �C  0.777  0.062  2.744  ...  3.601  1.179 -0.583
# 1  Standard Deviation   �C  1.950  1.950  1.950  ...  1.950  1.950  1.950
# 2  Temperature change   �C -1.743  2.465  3.919  ...  1.212  0.321 -3.201
# 3  Standard Deviation   �C  2.597  2.597  2.597  ...  2.597  2.597  2.597
# 4  Temperature change   �C  0.516  1.336  0.403  ...  3.390  0.748 -0.527
#
#    Y2013  Y2014  Y2015  Y2016  Y2017  Y2018  Y2019
# 0  1.233  1.755  1.943  3.416  1.201  1.996  2.951
# ...
